# %%
import glob 
import csv
import pandas as pd
import numpy as np
from scipy import stats 

import plotly.graph_objects as go
import plotly.express as px

pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 50)

# %%
merged_csvs = glob.glob('../raw_data_files_clean/merged_*')
merged_csvs.sort()

merged_csvs
# Out:
# ['../raw_data_files_clean/merged_adm.csv',
#  '../raw_data_files_clean/merged_assessment.csv',
#  '../raw_data_files_clean/merged_assessment_2022.csv',
#  '../raw_data_files_clean/merged_assessment_all_students.csv',
#  '../raw_data_files_clean/merged_demographics.csv',
#  '../raw_data_files_clean/merged_directory.csv',
#  '../raw_data_files_clean/merged_grad.csv']

# %%
flat_file = glob.glob('../data_for_analysis/2022_assessment_flat_file*')
demog = glob.glob('../data_for_analysis/2022_demog*')
demog
# Out:
# ['../data_for_analysis/2022_demog.csv']

# %%
def pull_files_and_create_df(raw_file_names): 
    df_list=[]
    for i in raw_file_names:
        name = i.split('/')[2].split('.')[0]
        globals()[f'df_{name}'] = pd.read_csv(i, low_memory=False)
        d = df_list.append(f'df_{name}')
    df_list.sort(reverse=True)
    return df_list

# %%
pull_files_and_create_df(merged_csvs)
pull_files_and_create_df(flat_file)
pull_files_and_create_df(demog)
# Out:
# ['df_2022_demog']

# %%
df_2022_assessment_flat_file[df_2022_assessment_flat_file['system_name']=='i3 Academy']
# Out:
#       system_code system_name  school_code                     school_name  \
# 1281          805  i3 Academy           10  i3 Academy - Elementary School
# 1282          805  i3 Academy           15      i3 Academy - Middle School
#
#       2022_percent_proficient_ela  2022_percent_proficient_math  \
# 1281                        26.57                          7.62
# 1282                        30.93                          9.18
#
#       2022_proficient_ela  2022_proficient_math  2022_tested_ela  \
# 1281              54.9999               16.0020            207.0
# 1282              30.3114                8.9964             98.0
#
#       2022_tested_math                      site_type     county is_charter  \
# 1281             210.0  Public Charter School Startup  Jefferson       True
# 1282              98.0  Public Charter School Startup  Jefferson       True
#
#      asian black_or_african_american american_indian_alaska_native  \
# 1281     *                       339                             *
# 1282     *                         *                             *
#
#      native_hawaiian_pacific_islander white two_or_more_races hispanic_latino  \
# 1281                                *    27                 *              13
# 1282                                *     *                 *               *
#
#       year  total_enrollment_2022  econ_disadv  foster  gen_ed  ...  \
# 1281  2022                  382.0        239.0     NaN   317.0  ...
# 1282  2022                   88.0         53.0     NaN    71.0  ...
#
#       military_pct_2022  swd_pct_2022  el_pct_2022  asian_pct_2022  \
# 1281                NaN      0.170157          NaN             NaN
# 1282                NaN      0.193182          NaN             NaN
#
#       black_or_african_american_pct_2022  \
# 1281                            0.887435
# 1282                                 NaN
#
#       american_indian_alaska_native_pct_2022  \
# 1281                                     NaN
# 1282                                     NaN
#
#       native_hawaiian_pacific_islander_pct_2022  white_pct_2022  \
# 1281                                        NaN        0.070681
# 1282                                        NaN             NaN
#
#       two_or_more_races_pct_2022  hispanic_latino_pct_2022  sum_pct_2022  \
# 1281                         NaN                  0.034031           NaN
# 1282                         NaN                       NaN           NaN
#
#       updated_district  updated_district_code  frl_pct_2022  \
# 1281   Birmingham City                  114.0        59.81%
# 1282   Birmingham City                  114.0        56.38%
#
#       total_frl_enrollment_2022  black_or_hispanic_pct_2022  \
# 1281                        423                    0.921466
# 1282                         94                         NaN
#
#       is_charter_district  2021_percent_proficient_ela  \
# 1281                 True                        25.69
# 1282                 True                          NaN
#
#       2021_percent_proficient_math  2021_proficient_ela  2021_proficient_math  \
# 1281                          3.66                 56.0              8.015985
# 1282                           NaN                  NaN                   NaN
#
#      2021_tested_ela  2021_tested_math 2021_2022_ela_change  \
# 1281      217.976319        219.015985                 0.88
# 1282             NaN               NaN                  NaN
#
#      2021_2022_math_change
# 1281                  3.96
# 1282                   NaN
#
# [2 rows x 60 columns]

# %%
df_district_charter_mapping = pd.DataFrame({'system_code':
    [800,51,802,802,808,801,803,805,805,810],
    'school_code':
    [10,220,10,15,10,10,10,10,15,10],
    'updated_district':
    ['Mobile County','Montgomery County','Montgomery County','Montgomery County','Perry County','Sumter County','Birmingham City','Birmingham City','Birmingham City','Homewood City'],
    'updated_district_code':[49,51,51,51,53,60,114,114,114,157]
})

# %%
df_directory_schools = df_merged_directory.loc[((df_merged_directory['is_charter']=='True') 
                                               | (df_merged_directory['is_charter']=='False'))
                                              & (df_merged_directory['school_code']!=0)
                                              & (df_merged_directory['school_code']!=1)
                                              & (df_merged_directory['nces_id'].notnull())].drop_duplicates()
df_directory_charter_schools = df_merged_directory.loc[(df_merged_directory['is_charter']=='True')]

# %%
df_directory_schools.columns
# Out:
# Index(['system_code', 'school_code', 'system_name', 'school_name', 'site_type',
#        'nces_id', 'is_charter', 'street', 'city', 'state', 'zip_5', 'county',
#        'file_year', 'opened_date'],
#       dtype='object')

# %%
df_merged_demographics.loc[df_merged_demographics['system_name']=='i3 Academy']
# Out:
#       year system_name                     school_name       grade  \
# 71    2022  i3 Academy                i3 Academy - LEA  All Grades
# 231   2022  i3 Academy  i3 Academy - Elementary School  All Grades
# 281   2022  i3 Academy      i3 Academy - Middle School  All Grades
# 1570  2021  i3 Academy  i3 Academy - Elementary School  All Grades
#
#           gender      ethnicity     sub_population total_student_count asian  \
# 71    All Gender  All Ethnicity  All SubPopulation                 470     *
# 231   All Gender  All Ethnicity  All SubPopulation                 382     *
# 281   All Gender  All Ethnicity  All SubPopulation                  88     *
# 1570  All Gender  All Ethnicity  All SubPopulation                 412     *
#
#      asian_% black_or_african_american black_or_african_american_%  \
# 71         *                       419                       89.15
# 231        *                       340                       89.01
# 281        *                         *                           *
# 1570       *                       370                       89.81
#
#      american_indian_/_alaska_native _american_indian_/_alaska_native_%  \
# 71                                 *                                  *
# 231                                *                                  *
# 281                                *                                  *
# 1570                               *                                  *
#
#      native_hawaiian_/_pacific_islander native_hawaiian_/_pacific_islander_%  \
# 71                                    *                                    *
# 231                                   *                                    *
# 281                                   *                                    *
# 1570                                  *                                    *
#
#      white white_% two_or_more_races two_or_more_races_%  file_year
# 71      40    8.51                 *                   *       2022
# 231     34    8.90                 *                   *       2022
# 281      *       *                 *                   *       2022
# 1570    35    8.50                 *                   *       2021

# %%
df_directory_schools.loc[df_directory_schools['system_name']=='i3 Academy']
# Out:
#      system_code  school_code system_name                     school_name  \
# 1603         805           10  i3 Academy  i3 Academy - Elementary School
# 1604         805           15  i3 Academy      i3 Academy - Middle School
# 5884         805           10  i3 Academy  i3 Academy - Elementary School
#
#                           site_type        nces_id is_charter  \
# 1603  Public Charter School Startup  10020402476.0       True
# 1604  Public Charter School Startup  10020402510.0       True
# 5884  Public Charter School Startup  10020402476.0       True
#
#                            street        city state       zip_5     county  \
# 1603  55th Place 1st Avenue South  Birmingham    AL       35212  Jefferson
# 1604        7901 1st Avenue North  Birmingham    AL  35206-      Jefferson
# 5884  55th Place 1st Avenue South  Birmingham    AL       35212  Jefferson
#
#       file_year opened_date
# 1603       2022      7/1/20
# 1604       2022      7/1/21
# 5884       2021      7/1/20

# %%
df_2022_demog['file_year'] = 2022

# %%
df_directory_demog_merged = (
    df_directory_schools
    .merge(df_merged_demographics, on=['system_name','school_name','file_year'], how='outer')
)

df_directory_demog_merged
# Out:
#       system_code  school_code             system_name  \
# 0             600       9040.0  Al Inst Deaf And Blind
# 1             210       4999.0  Alabama Youth Services
# 2             103         10.0          Alabaster City
# 3             103          5.0          Alabaster City
# 4             103       4999.0          Alabaster City
# ...           ...          ...                     ...
# 15089         NaN          NaN           Walker County
# 15090         NaN          NaN       Washington County
# 15091         NaN          NaN           Wilcox County
# 15092         NaN          NaN           Winfield City
# 15093         NaN          NaN          Winston County
#
#                                        school_name  \
# 0                    E H Gentry Technical Facility
# 1      Spec Ed Private Services (Child Count Only)
# 2                     Creek View Elementary School
# 3                   Meadow View  Elementary School
# 4      Spec Ed Private Services (Child Count Only)
# ...                                            ...
# 15089                                Walker County
# 15090                            Washington County
# 15091                                Wilcox County
# 15092                                Winfield City
# 15093                               Winston County
#
#                                    site_type        nces_id is_charter  \
# 0      State Supported School Other Facility  10000901406.0      False
# 1       Special Education - Private Services  10000202249.0      False
# 2                      Public Regular School  10019001815.0      False
# 3                      Public Regular School  10019001460.0      False
# 4       Special Education - Private Services  10019002216.0      False
# ...                                      ...            ...        ...
# 15089                                    NaN            NaN        NaN
# 15090                                    NaN            NaN        NaN
# 15091                                    NaN            NaN        NaN
# 15092                                    NaN            NaN        NaN
# 15093                                    NaN            NaN        NaN
#
#                               street       city state       zip_5      county  \
# 0                  1105 Fort Lashley  Talladega    AL       35160   Talladega
# 1        1000 Industrial School Road   Mt Meigs    AL  36057-0066  Montgomery
# 2                    8568 Highway 17    Maylene    AL       35114      Shelby
# 3                     2800 Smokey Rd  Alabaster    AL       35007      Shelby
# 4      1953 Municipal Way, Suite 200  Alabaster    AL       35007     Autauga
# ...                              ...        ...   ...         ...         ...
# 15089                            NaN        NaN   NaN         NaN         NaN
# 15090                            NaN        NaN   NaN         NaN         NaN
# 15091                            NaN        NaN   NaN         NaN         NaN
# 15092                            NaN        NaN   NaN         NaN         NaN
# 15093                            NaN        NaN   NaN         NaN         NaN
#
#        file_year opened_date    year       grade      gender      ethnicity  \
# 0           2022         NaN     NaN         NaN         NaN            NaN
# 1           2022         NaN     NaN         NaN         NaN            NaN
# 2           2022      7/1/13  2022.0  All Grades  All Gender  All Ethnicity
# 3           2022      7/1/13  2022.0  All Grades  All Gender  All Ethnicity
# 4           2022      8/1/13     NaN         NaN         NaN            NaN
# ...          ...         ...     ...         ...         ...            ...
# 15089       2015         NaN  2015.0  All Grades  All Gender  All Ethnicity
# 15090       2015         NaN  2015.0  All Grades  All Gender  All Ethnicity
# 15091       2015         NaN  2015.0  All Grades  All Gender  All Ethnicity
# 15092       2015         NaN  2015.0  All Grades  All Gender  All Ethnicity
# 15093       2015         NaN  2015.0  All Grades  All Gender  All Ethnicity
#
#           sub_population total_student_count asian asian_%  \
# 0                    NaN                 NaN   NaN     NaN
# 1                    NaN                 NaN   NaN     NaN
# 2      All SubPopulation                 911    11       ~
# 3      All SubPopulation                 937     *       *
# 4                    NaN                 NaN   NaN     NaN
# ...                  ...                 ...   ...     ...
# 15089  All SubPopulation                7899     *       *
# 15090  All SubPopulation                3024     *       *
# 15091  All SubPopulation                1869     *       *
# 15092  All SubPopulation                1263     *       *
# 15093  All SubPopulation                2545     *       *
#
#       black_or_african_american black_or_african_american_%  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           180                       19.76
# 3                           195                       20.81
# 4                           NaN                         NaN
# ...                         ...                         ...
# 15089                       451                        5.71
# 15090                       820                       27.12
# 15091                      1858                           ~
# 15092                        42                           ~
# 15093                         *                           *
#
#       american_indian_/_alaska_native _american_indian_/_alaska_native_%  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 137                              15.04
# 3                                 189                              20.17
# 4                                 NaN                                NaN
# ...                               ...                                ...
# 15089                               *                                  *
# 15090                             302                               9.99
# 15091                               *                                  *
# 15092                               *                                  *
# 15093                               *                                  *
#
#       native_hawaiian_/_pacific_islander native_hawaiian_/_pacific_islander_%  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                      *                                    *
# 3                                      *                                    *
# 4                                    NaN                                  NaN
# ...                                  ...                                  ...
# 15089                                  *                                    *
# 15090                                  *                                    *
# 15091                                  *                                    *
# 15092                                  *                                    *
# 15093                                  *                                    *
#
#       white white_% two_or_more_races two_or_more_races_%
# 0       NaN     NaN               NaN                 NaN
# 1       NaN     NaN               NaN                 NaN
# 2       551   60.48                29                   ~
# 3       518   55.28                24                   ~
# 4       NaN     NaN               NaN                 NaN
# ...     ...     ...               ...                 ...
# 15089  7255   91.85               174                   ~
# 15090  1855   61.34                40                   ~
# 15091     *       *                 *                   *
# 15092  1179   93.35                31                   ~
# 15093  2513       ~                16                   ~
#
# [15094 rows x 32 columns]

# %%
df_2022_demog[df_2022_demog['system_name']=='i3 Academy']

df_2022_demog['school_name'] = (
    df_2022_demog['school_name']
    .replace('i3 Academy - LEA', 'i3 Academy')
    .replace('LEAD Academy - LEA', 'LEAD Academy'))

# %%
for i in ['system_code','school_code']:
    df_district_charter_mapping[i] = df_district_charter_mapping[i].astype('string')
    df_merged_directory[i] = df_merged_directory[i].astype('string')
    
df_entities = (
    df_merged_directory
    .merge(df_district_charter_mapping, on=['system_code','school_code'], how='left')
    .merge(df_2022_demog, on=['system_name','school_name','file_year'], how='outer')
)
df_entities = df_entities.loc[((df_entities['site_type'] == 'Central Office' )|
# (df_entities['site_type'] == 'State Board District' )|
# (df_entities['site_type'] == 'State Supported School Special Education School' )|
(df_entities['site_type'] == 'Public Regular School' )|
(df_entities['site_type'] == 'Public Alternative School' )|
(df_entities['site_type'] == 'Public Virtual School' )|
(df_entities['site_type'] == 'Public Special Education School' )|
(df_entities['site_type'] == 'Public Magnet School' )|
(df_entities['site_type'] == 'Public Charter School Startup' )|
(df_entities['site_type'] == 'Public Charter School - Converted' )|
(df_entities['site_type'] == 'Regular School with Magnet Program' )|
(df_entities['site_type'] == 'Special Education School (No Detail)'))
                             & (df_entities['file_year']==2022)]

df_entities[df_entities['school_code']=='0']
# Out:
#      system_code school_code                                    system_name  \
# 0            999           0          Alabama State Department of Education
# 41           601           0  Alabama Specialized Treatment Centers (ALSTC)
# 51           210           0                         Alabama Youth Services
# 61           103           0                                 Alabaster City
# 74           101           0                               Albertville City
# ...          ...         ...                                            ...
# 4184          64           0                                  Walker County
# 4212          65           0                              Washington County
# 4236          66           0                                  Wilcox County
# 4250         204           0                                  Winfield City
# 4261          67           0                                 Winston County
#
#                                         school_name       site_type   nces_id  \
# 0             Alabama State Department of Education  Central Office       NaN
# 41    Alabama Specialized Treatment Centers (ALSTC)  Central Office       NaN
# 51                           Alabama Youth Services  Central Office  100002.0
# 61                                   Alabaster City  Central Office  100190.0
# 74                                 Albertville City  Central Office  100005.0
# ...                                             ...             ...       ...
# 4184                                  Walker County  Central Office  103450.0
# 4212                              Washington County  Central Office  103480.0
# 4236                                  Wilcox County  Central Office  103510.0
# 4250                                  Winfield City  Central Office  103540.0
# 4261                                 Winston County  Central Office  103580.0
#
#      is_charter                                         street  \
# 0           NaN  50. N. Ripley Street, Gordon Persons Building
# 41          NaN  50. N. Ripley Street, Gordon Persons Building
# 51          NaN                    1000 Industrial School Road
# 61          NaN                              10111 Highway 119
# 74          NaN                            8379 US Highway 431
# ...         ...                                            ...
# 4184        NaN                                1710 Alabama Av
# 4212        NaN                                 229 Granade St
# 4236        NaN                               75 Camden Bypass
# 4250        NaN                                  481 Apple Ave
# 4261        NaN                              25101 Highway 195
#
#                 city state       zip_5      county  file_year opened_date  \
# 0         Montgomery    AL       36104  Montgomery       2022      1/1/01
# 41        Montgomery    AL       36104  Montgomery       2022      8/1/21
# 51         Mt. Meigs    AL  36057-0066  Montgomery       2022      1/1/01
# 61         Alabaster    AL       35007      Shelby       2022      7/1/13
# 74       Albertville    AL  35950-0025    Marshall       2022         NaN
# ...              ...   ...         ...         ...        ...         ...
# 4184          Jasper    AL  35501-4966      Walker       2022         NaN
# 4212          Chatom    AL       36518  Washington       2022         NaN
# 4236          Camden    AL       36726      Wilcox       2022      1/1/01
# 4250        Winfield    AL       35594      Marion       2022      1/1/01
# 4261  Double Springs    AL       35553     Winston       2022         NaN
#
#      updated_district  updated_district_code  asian black_or_african_american  \
# 0                 NaN                    NaN  11099                    235270
# 41                NaN                    NaN    NaN                       NaN
# 51                NaN                    NaN    NaN                       NaN
# 61                NaN                    NaN     77                      1399
# 74                NaN                    NaN     24                       254
# ...               ...                    ...    ...                       ...
# 4184              NaN                    NaN      *                       397
# 4212              NaN                    NaN      *                       594
# 4236              NaN                    NaN      *                      1293
# 4250              NaN                    NaN      *                        60
# 4261              NaN                    NaN      *                        18
#
#      american_indian_alaska_native native_hawaiian_pacific_islander   white  \
# 0                             6455                              854  385045
# 41                             NaN                              NaN     NaN
# 51                             NaN                              NaN     NaN
# 61                              31                                *    3396
# 74                              28                                *    2168
# ...                            ...                              ...     ...
# 4184                            19                                *    6240
# 4212                           212                                *    1655
# 4236                             *                                *      15
# 4250                             *                                *    1108
# 4261                             *                                *    2226
#
#      two_or_more_races hispanic_latino    year  total_enrollment_2022  \
# 0                22524           74561  2022.0               735808.0
# 41                 NaN             NaN     NaN                    NaN
# 51                 NaN             NaN     NaN                    NaN
# 61                  71            1332  2022.0                 6315.0
# 74                 145            3235  2022.0                 5856.0
# ...                ...             ...     ...                    ...
# 4184               170             283  2022.0                 7118.0
# 4212                42              20  2022.0                 2529.0
# 4236                 *               *  2022.0                 1316.0
# 4250                23              40  2022.0                 1242.0
# 4261                13              41  2022.0                 2299.0
#
#       econ_disadv  foster    gen_ed  homeless  migrant  military       swd  \
# 0        351049.0  2754.0  604862.0    7819.0   1292.0   14646.0  130946.0
# 41            NaN     NaN       NaN       NaN      NaN       NaN       NaN
# 51            NaN     NaN       NaN       NaN      NaN       NaN       NaN
# 61         2201.0    20.0    5464.0      48.0      NaN     128.0     851.0
# 74         2716.0    20.0    5045.0      71.0    304.0     120.0     811.0
# ...           ...     ...       ...       ...      ...       ...       ...
# 4184       4087.0    59.0    5433.0      91.0      NaN      69.0    1685.0
# 4212       1247.0    12.0    2065.0      19.0    143.0       NaN     464.0
# 4236       1091.0     NaN    1140.0      89.0      NaN       NaN     176.0
# 4250        540.0     NaN    1035.0       NaN      NaN       NaN     207.0
# 4261       1112.0    14.0    1740.0       NaN      NaN       NaN     559.0
#
#            el  econ_disadv_pct_2022  foster_pct_2022  gen_ed_pct_2022  \
# 0     36956.0              0.477093         0.003743         0.822038
# 41        NaN                   NaN              NaN              NaN
# 51        NaN                   NaN              NaN              NaN
# 61      554.0              0.348535         0.003167         0.865241
# 74     1488.0              0.463798         0.003415         0.861510
# ...       ...                   ...              ...              ...
# 4184    121.0              0.574178         0.008289         0.763276
# 4212      NaN              0.493080         0.004745         0.816528
# 4236      NaN              0.829027              NaN         0.866261
# 4250     21.0              0.434783              NaN         0.833333
# 4261      NaN              0.483689         0.006090         0.756851
#
#       homeless_pct_2022  migrant_pct_2022  military_pct_2022  swd_pct_2022  \
# 0              0.010626          0.001756           0.019905      0.177962
# 41                  NaN               NaN                NaN           NaN
# 51                  NaN               NaN                NaN           NaN
# 61             0.007601               NaN           0.020269      0.134759
# 74             0.012124          0.051913           0.020492      0.138490
# ...                 ...               ...                ...           ...
# 4184           0.012784               NaN           0.009694      0.236724
# 4212           0.007513          0.056544                NaN      0.183472
# 4236           0.067629               NaN                NaN      0.133739
# 4250                NaN               NaN                NaN      0.166667
# 4261                NaN               NaN                NaN      0.243149
#
#       el_pct_2022  asian_pct_2022  black_or_african_american_pct_2022  \
# 0        0.050225        0.015084                            0.319744
# 41            NaN             NaN                                 NaN
# 51            NaN             NaN                                 NaN
# 61       0.087728        0.012193                            0.221536
# 74       0.254098        0.004098                            0.043374
# ...           ...             ...                                 ...
# 4184     0.016999             NaN                            0.055774
# 4212          NaN             NaN                            0.234875
# 4236          NaN             NaN                            0.982523
# 4250     0.016908             NaN                            0.048309
# 4261          NaN             NaN                            0.007829
#
#       american_indian_alaska_native_pct_2022  \
# 0                                   0.008773
# 41                                       NaN
# 51                                       NaN
# 61                                  0.004909
# 74                                  0.004781
# ...                                      ...
# 4184                                0.002669
# 4212                                0.083828
# 4236                                     NaN
# 4250                                     NaN
# 4261                                     NaN
#
#       native_hawaiian_pacific_islander_pct_2022  white_pct_2022  \
# 0                                      0.001161        0.523295
# 41                                          NaN             NaN
# 51                                          NaN             NaN
# 61                                          NaN        0.537767
# 74                                          NaN        0.370219
# ...                                         ...             ...
# 4184                                        NaN        0.876651
# 4212                                        NaN        0.654409
# 4236                                        NaN        0.011398
# 4250                                        NaN        0.892110
# 4261                                        NaN        0.968247
#
#       two_or_more_races_pct_2022  hispanic_latino_pct_2022  sum_pct_2022
# 0                       0.030611                  0.101332           1.0
# 41                           NaN                       NaN           NaN
# 51                           NaN                       NaN           NaN
# 61                      0.011243                  0.210926           NaN
# 74                      0.024761                  0.552425           NaN
# ...                          ...                       ...           ...
# 4184                    0.023883                  0.039758           NaN
# 4212                    0.016607                  0.007908           NaN
# 4236                         NaN                       NaN           NaN
# 4250                    0.018519                  0.032206           NaN
# 4261                    0.005655                  0.017834           NaN
#
# [155 rows x 49 columns]

# %%
df_entities.columns
# Out:
# Index(['system_code', 'school_code', 'system_name', 'school_name', 'site_type',
#        'nces_id', 'is_charter', 'street', 'city', 'state', 'zip_5', 'county',
#        'file_year', 'opened_date', 'updated_district', 'updated_district_code',
#        'asian', 'black_or_african_american', 'american_indian_alaska_native',
#        'native_hawaiian_pacific_islander', 'white', 'two_or_more_races',
#        'hispanic_latino', 'year', 'total_enrollment_2022', 'econ_disadv',
#        'foster', 'gen_ed', 'homeless', 'migrant', 'military', 'swd', 'el',
#        'econ_disadv_pct_2022', 'foster_pct_2022', 'gen_ed_pct_2022',
#        'homeless_pct_2022', 'migrant_pct_2022', 'military_pct_2022',
#        'swd_pct_2022', 'el_pct_2022', 'asian_pct_2022',
#        'black_or_african_american_pct_2022',
#        'american_indian_alaska_native_pct_2022',
#        'native_hawaiian_pacific_islander_pct_2022', 'white_pct_2022',
#        'two_or_more_races_pct_2022', 'hispanic_latino_pct_2022',
#        'sum_pct_2022'],
#       dtype='object')

# %% [markdown]
# Entities would be one row per entity (district or school) with type (district, school), district code, district name, school code, school name, is_charter, neighboring district (or whatever you called that for charters in our analysis), and maybe most recent enrollment total and % by race, group (as columns), so wide.  I think just those currently operating would be fine.

# %%
df_entities = df_entities[['system_code', 'school_code', 'system_name', 'school_name', 'site_type',
      'is_charter', 'updated_district', 'updated_district_code',
       'total_enrollment_2022',
       'econ_disadv_pct_2022', 'foster_pct_2022', 'gen_ed_pct_2022',
       'homeless_pct_2022', 'migrant_pct_2022', 'military_pct_2022',
       'swd_pct_2022', 'el_pct_2022', 'asian_pct_2022',
       'black_or_african_american_pct_2022',
       'american_indian_alaska_native_pct_2022',
       'native_hawaiian_pacific_islander_pct_2022', 'white_pct_2022',
       'two_or_more_races_pct_2022', 'hispanic_latino_pct_2022',
       'sum_pct_2022']]

# %%
# district code, district name, school code, school name, metric name, group, grade, year, value, and n-size
df_merged_assessment
# Out:
#                                    system_name  \
# 0        Alabama State Department of Education
# 1        Alabama State Department of Education
# 2        Alabama State Department of Education
# 3        Alabama State Department of Education
# 4        Alabama State Department of Education
# ...                                        ...
# 5918101                         Winston County
# 5918102                         Winston County
# 5918103                         Winston County
# 5918104                         Winston County
# 5918105                         Winston County
#
#                                    school_name  subject       grade  \
# 0        Alabama State Department of Education     Math  All Grades
# 1        Alabama State Department of Education     Math  All Grades
# 2        Alabama State Department of Education     Math  All Grades
# 3        Alabama State Department of Education     Math  All Grades
# 4        Alabama State Department of Education     Math  All Grades
# ...                                        ...      ...         ...
# 5918101                         Winston County  Reading    Grade 10
# 5918102                         Winston County  Reading    Grade 10
# 5918103                         Winston County  Reading    Grade 10
# 5918104                         Winston County  Reading    Grade 10
# 5918105                         Winston County  Reading    Grade 10
#
#             tested proficient               race        ethnicity  \
# 0        378006.00     102938           All Race    All Ethnicity
# 1        378006.00     102938           All Race    All Ethnicity
# 2         20237.00       2095           All Race    All Ethnicity
# 3         20237.00       2095           All Race    All Ethnicity
# 4          3781.00        409           All Race    All Ethnicity
# ...            ...        ...                ...              ...
# 5918101          *          *  Two or more races    All Ethnicity
# 5918102          *          *  Two or more races  Other Ethnicity
# 5918103          *          *  Two or more races  Other Ethnicity
# 5918104          *          *  Two or more races  Other Ethnicity
# 5918105          *          *  Two or more races  Other Ethnicity
#
#                                     sub_population     grade.1  \
# 0                                All SubPopulation  All Grades
# 1                                All SubPopulation  All Grades
# 2        Students with Limited English Proficiency  All Grades
# 3        Students with Limited English Proficiency  All Grades
# 4                                         Homeless  All Grades
# ...                                            ...         ...
# 5918101                 General Education Students    Grade 10
# 5918102                          All SubPopulation    Grade 10
# 5918103                          All SubPopulation    Grade 10
# 5918104                 General Education Students    Grade 10
# 5918105                 General Education Students    Grade 10
#
#         participation_rate proficient_rate         file_source  file_year  \
# 0                      NaN           27.23  df_assessment_2022       2022
# 1                      NaN           27.23  df_assessment_2022       2022
# 2                      NaN           10.35  df_assessment_2022       2022
# 3                      NaN           10.35  df_assessment_2022       2022
# 4                      NaN           10.82  df_assessment_2022       2022
# ...                    ...             ...                 ...        ...
# 5918101                  *               *  df_assessment_2015       2015
# 5918102                  *               *  df_assessment_2015       2015
# 5918103                  *               *  df_assessment_2015       2015
# 5918104                  *               *  df_assessment_2015       2015
# 5918105                  *               *  df_assessment_2015       2015
#
#          system_code  school_code                  site_type   nces_id  \
# 0              999.0          0.0             Central Office       NaN
# 1              999.0          1.0       State Board District       NaN
# 2              999.0          0.0             Central Office       NaN
# 3              999.0          1.0       State Board District       NaN
# 4              999.0          0.0             Central Office       NaN
# ...              ...          ...                        ...       ...
# 5918101         67.0          1.0  Public Board of Education       NaN
# 5918102         67.0          0.0             Central Office  103580.0
# 5918103         67.0          1.0  Public Board of Education       NaN
# 5918104         67.0          0.0             Central Office  103580.0
# 5918105         67.0          1.0  Public Board of Education       NaN
#
#         is_charter                                         street  \
# 0              NaN  50. N. Ripley Street, Gordon Persons Building
# 1              NaN                            3071 Teal Court
# 2              NaN  50. N. Ripley Street, Gordon Persons Building
# 3              NaN                            3071 Teal Court
# 4              NaN  50. N. Ripley Street, Gordon Persons Building
# ...            ...                                            ...
# 5918101        NaN                              25101 Highway 195
# 5918102        NaN                              25101 Highway 195
# 5918103        NaN                              25101 Highway 195
# 5918104        NaN                              25101 Highway 195
# 5918105        NaN                              25101 Highway 195
#
#                    city state  zip_5      county opened_date
# 0            Montgomery    AL  36104  Montgomery      1/1/01
# 1                Mobile    AL  36695     Baldwin      1/1/00
# 2            Montgomery    AL  36104  Montgomery      1/1/01
# 3                Mobile    AL  36695     Baldwin      1/1/00
# 4            Montgomery    AL  36104  Montgomery      1/1/01
# ...                 ...   ...    ...         ...         ...
# 5918101  Double Springs    AL  35553     Winston         NaN
# 5918102  Double Springs    AL  35553     Winston         NaN
# 5918103  Double Springs    AL  35553     Winston         NaN
# 5918104  Double Springs    AL  35553     Winston         NaN
# 5918105  Double Springs    AL  35553     Winston         NaN
#
# [5918106 rows x 25 columns]

# %%
asmt_race = df_merged_assessment[(df_merged_assessment['sub_population']=='All SubPopulation') & 
                    (df_merged_assessment['ethnicity']=='Other Ethnicity')  & 
                    (df_merged_assessment['race']!='All Race')].copy()

asmt_race['group']=asmt_race['race']

asmt_hispanic = df_merged_assessment[(df_merged_assessment['sub_population']=='All SubPopulation') & 
                    (df_merged_assessment['ethnicity']=='Hispanic/Latino')  & 
                    (df_merged_assessment['race']=='All Race')].copy()

asmt_hispanic['group']=asmt_hispanic['ethnicity']

asmt_subpop = df_merged_assessment[(df_merged_assessment['sub_population']!='All SubPopulation') & 
                    (df_merged_assessment['ethnicity']=='All Ethnicity')  & 
                    (df_merged_assessment['race']=='All Race')].copy()

asmt_subpop['group']=asmt_subpop['sub_population']


asmt_all = df_merged_assessment[(df_merged_assessment['sub_population']=='All SubPopulation') & 
                    (df_merged_assessment['ethnicity']=='All Ethnicity')  & 
                    (df_merged_assessment['race']=='All Race')].copy()

asmt_all['group']= 'All Students'

# %%
df_asmt = pd.concat([asmt_race,asmt_subpop,asmt_hispanic,asmt_all])

df_asmt['metric']='Assessment Proficiency'
df_asmt = df_asmt[['file_year','metric','system_code', 'school_code', 'system_name', 'school_name',
       'group', 'subject', 'grade', 'tested',
       'proficient', 'proficient_rate']]


df_asmt = df_asmt.rename(columns={'file_year':'year',
                        'tested':'total_n',
                       'proficient':'metric_n',
                       'proficient_rate':'metric_pct'})

# %%
df_asmt
# Out:
#          year                  metric  system_code  school_code  \
# 86       2022  Assessment Proficiency        999.0          0.0
# 87       2022  Assessment Proficiency        999.0          1.0
# 140      2022  Assessment Proficiency        999.0          0.0
# 141      2022  Assessment Proficiency        999.0          1.0
# 194      2022  Assessment Proficiency        999.0          0.0
# ...       ...                     ...          ...          ...
# 5917851  2015  Assessment Proficiency         67.0          1.0
# 5917918  2015  Assessment Proficiency         67.0          0.0
# 5917919  2015  Assessment Proficiency         67.0          1.0
# 5918022  2015  Assessment Proficiency         67.0          0.0
# 5918023  2015  Assessment Proficiency         67.0          1.0
#
#                                    system_name  \
# 86       Alabama State Department of Education
# 87       Alabama State Department of Education
# 140      Alabama State Department of Education
# 141      Alabama State Department of Education
# 194      Alabama State Department of Education
# ...                                        ...
# 5917851                         Winston County
# 5917918                         Winston County
# 5917919                         Winston County
# 5918022                         Winston County
# 5918023                         Winston County
#
#                                    school_name                          group  \
# 86       Alabama State Department of Education                          Asian
# 87       Alabama State Department of Education                          Asian
# 140      Alabama State Department of Education      Black or African American
# 141      Alabama State Department of Education      Black or African American
# 194      Alabama State Department of Education  American Indian/Alaska Native
# ...                                        ...                            ...
# 5917851                         Winston County                   All Students
# 5917918                         Winston County                   All Students
# 5917919                         Winston County                   All Students
# 5918022                         Winston County                   All Students
# 5918023                         Winston County                   All Students
#
#          subject       grade    total_n metric_n metric_pct
# 86          Math  All Grades    5942.00     3767      63.40
# 87          Math  All Grades    5942.00     3767      63.40
# 140         Math  All Grades  120612.00    12910      10.70
# 141         Math  All Grades  120612.00    12910      10.70
# 194         Math  All Grades    3579.00     1104      30.85
# ...          ...         ...        ...      ...        ...
# 5917851  Reading    Grade 07          *       79      41.80
# 5917918  Reading    Grade 08          *      105      42.34
# 5917919  Reading    Grade 08          *      105      42.34
# 5918022  Reading    Grade 10          *      123      64.74
# 5918023  Reading    Grade 10          *      123      64.74
#
# [1098062 rows x 12 columns]

# %%
grad_race = df_merged_grad[(df_merged_grad['sub_population']=='All SubPopulation') & 
                    (df_merged_grad['ethnicity']=='Other Ethnicity')  & 
                    (df_merged_grad['race']!='All Race')].copy()

grad_race['group']=asmt_race['race']

grad_hispanic = df_merged_grad[(df_merged_grad['sub_population']=='All SubPopulation') & 
                    (df_merged_grad['ethnicity']=='Hispanic/Latino')  & 
                    (df_merged_grad['race']=='All Race')].copy()

grad_hispanic['group']=asmt_hispanic['ethnicity']

grad_subpop = df_merged_grad[(df_merged_grad['sub_population']!='All SubPopulation') & 
                    (df_merged_grad['ethnicity']=='All Ethnicity')  & 
                    (df_merged_grad['race']=='All Race')].copy()

grad_subpop['group']=asmt_subpop['sub_population']

grad_all = df_merged_assessment[(df_merged_assessment['sub_population']=='All SubPopulation') & 
                    (df_merged_assessment['ethnicity']=='All Ethnicity')  & 
                    (df_merged_assessment['race']=='All Race')].copy()

grad_all['group']= 'All Students'

# %%
asmt_subpop[['file_year','subject']].drop_duplicates()
# Out:
#          file_year  subject
# 2             2022     Math
# 474025        2022      ELA
# 948098        2021     Math
# 1406021       2021      ELA
# 1864033       2019     Math
# 2317220       2019      ELA
# 2770631       2018     Math
# 3212989       2018      ELA
# 3655556       2017     Math
# 4036699       2017      ELA
# 4417842       2016     Math
# 4792029       2016  Reading
# 5166216       2015     Math
# 5542231       2015  Reading

# %%
df_grad_ccr = pd.concat([grad_race,grad_subpop,grad_hispanic,grad_all])

df_grad = df_grad_ccr.copy()
df_grad['subject']=np.NaN

df_grad['metric']='Graduation'

df_grad = df_grad[['file_year','metric','system_code', 'school_code', 'system_name', 'school_name',
       'group', 'subject', 'grade', 'student_count',
       'graduates', 'graduation_%']]


df_grad = df_grad.rename(columns={'file_year':'year',
                        'student_count':'total_n',
                       'graduates':'metric_n',
                       'graduation_%':'metric_pct'})

df_ccr = df_grad_ccr.copy()
df_ccr['subject']=np.NaN

df_ccr['metric']='CCR'

df_ccr = df_ccr[['file_year','metric','system_code', 'school_code', 'system_name', 'school_name',
       'group', 'subject', 'grade', 'student_count',
       'ccr_attainment', 'ccr_attainment_%']]


df_ccr = df_ccr.rename(columns={'file_year':'year',
                        'student_count':'total_n',
                       'ccr_attainment':'metric_n',
                       'ccr_attainment_%':'metric_pct'})

df_ccr.columns
# Out:
# Index(['year', 'metric', 'system_code', 'school_code', 'system_name',
#        'school_name', 'group', 'subject', 'grade', 'total_n', 'metric_n',
#        'metric_pct'],
#       dtype='object')

# %%
df_merged_grad
# Out:
#       year              sub_population                            system_name  \
# 0     2022           All SubPopulation  Alabama State Department of Education
# 1     2022           All SubPopulation  Alabama State Department of Education
# 2     2022           All SubPopulation                          Morgan County
# 3     2022           All SubPopulation                         Baldwin County
# 4     2022           All SubPopulation                           Coosa County
# ...    ...                         ...                                    ...
# 6943  2018  Economically Disadvantaged                        Tuscaloosa City
# 6944  2018  Economically Disadvantaged                         Tuscumbia City
# 6945  2018  Economically Disadvantaged                    Vestavia Hills City
# 6946  2018  Economically Disadvantaged                          Winfield City
# 6947  2018  Economically Disadvantaged                        Trussville City
#
#                                 school_name       grade      gender      race  \
# 0     Alabama State Department of Education  All Grades  All Gender  All Race
# 1     Alabama State Department of Education  All Grades  All Gender  All Race
# 2               Albert P Brewer High School  All Grades  All Gender  All Race
# 3                Baldwin County High School  All Grades  All Gender  All Race
# 4                       Central High School  All Grades  All Gender  All Race
# ...                                     ...         ...         ...       ...
# 6943                    Central High School  All Grades  All Gender  All Race
# 6944                    Deshler High School  All Grades  All Gender  All Race
# 6945             Vestavia Hills High School  All Grades  All Gender  All Race
# 6946                   Winfield High School  All Grades  All Gender  All Race
# 6947          Hewitt-Trussville High School  All Grades  All Gender  All Race
#
#           ethnicity student_count graduates graduation_% ccr_attainment  \
# 0     All Ethnicity         51440     46644        90.68          39340
# 1     All Ethnicity         51440     46644        90.68          39340
# 2     All Ethnicity           161       139        86.34            137
# 3     All Ethnicity           219       179        81.74            181
# 4     All Ethnicity            50         *            *             30
# ...             ...           ...       ...          ...            ...
# 6943  All Ethnicity           126       103        81.75             52
# 6944  All Ethnicity            49         *            *             24
# 6945  All Ethnicity            55         *            *             41
# 6946  All Ethnicity            26         *            *              *
# 6947  All Ethnicity            38         *            *             27
#
#      ccr_attainment_%   file_source  file_year  system_code  school_code  \
# 0               76.48  df_grad_2022       2022          999          0.0
# 1               76.48  df_grad_2022       2022          999          1.0
# 2               85.09  df_grad_2022       2022           52          5.0
# 3               82.65  df_grad_2022       2022            2          5.0
# 4               60.00  df_grad_2022       2022           19          5.0
# ...               ...           ...        ...          ...          ...
# 6943            41.27  df_grad_2018       2018          200        160.0
# 6944            48.98  df_grad_2018       2018          201         10.0
# 6945            74.55  df_grad_2018       2018          202         20.0
# 6946                *  df_grad_2018       2018          204         20.0
# 6947            71.05  df_grad_2018       2018          205        890.0
#
#                   site_type       nces_id is_charter  \
# 0            Central Office           NaN        NaN
# 1      State Board District           NaN        NaN
# 2     Public Regular School  1.024800e+10      False
# 3     Public Regular School  1.002700e+10      False
# 4     Public Regular School  1.009000e+10      False
# ...                     ...           ...        ...
# 6943  Public Regular School  1.033600e+10      False
# 6944  Public Regular School  1.034200e+10      False
# 6945  Public Regular School  1.034300e+10      False
# 6946  Public Regular School  1.035400e+10      False
# 6947  Public Regular School  1.000130e+10      False
#
#                                              street            city state  \
# 0     50. N. Ripley Street, Gordon Persons Building      Montgomery    AL
# 1                               3071 Teal Court              Mobile    AL
# 2                                         59 Eva Rd      Somerville    AL
# 3                                      One Tiger Dr     Bay Minette    AL
# 4                           97 Coosa County Road 75        Rockford    AL
# ...                                             ...             ...   ...
# 6943                                905 15th Street      Tuscaloosa    AL
# 6944                             200 N Commons East       Tuscumbia    AL
# 6945                              2235 Lime Rock Rd  Vestavia Hills    AL
# 6946                                232 Pirate Cove        Winfield    AL
# 6947                             6450 Husky Parkway      Trussville    AL
#
#            zip_5      county opened_date                   sub_group
# 0          36104  Montgomery      1/1/01                         All
# 1          36695     Baldwin      1/1/00                         All
# 2     35670-6423      Morgan      1/1/94                         All
# 3     36507-3300     Baldwin      1/1/94                         All
# 4     35136-3710       Coosa      1/1/94                         All
# ...          ...         ...         ...                         ...
# 6943       35401  Tuscaloosa      1/1/94  Economically Disadvantaged
# 6944  35674-1299     Colbert     5/28/97  Economically Disadvantaged
# 6945  35216-3399   Jefferson         NaN  Economically Disadvantaged
# 6946       35594      Marion      1/1/01  Economically Disadvantaged
# 6947  35173-6400   Jefferson     5/31/05  Economically Disadvantaged
#
# [6948 rows x 27 columns]

# %%
df_metrics = pd.concat([df_asmt,df_ccr,df_grad,])

# %%
with pd.ExcelWriter('../data_for_analysis/directory.xlsx') as writer:  
    df_directory_charter_schools.to_excel(writer, sheet_name='directory_by_charter')
    df_directory_demog_merged.to_excel(writer, sheet_name='directory_demographics')

    
df_entities.to_csv('../data_for_analysis/entities.csv', encoding='utf-8', index=False)
df_metrics.to_csv('../data_for_analysis/metrics.csv', encoding='utf-8', index=False)

# %%
df_metrics['metric'].unique()
# Out:
# array(['Assessment Proficiency', 'CCR', 'Graduation'], dtype=object)

# %%
# district code, district name, school code, school name, metric name, group, grade, year, value, and n-size
